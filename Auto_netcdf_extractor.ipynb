# %%
import os
#############################( Run This only at start) ################################
# This script makes folder name 1 2 3 4 upto 156 
# made with love by Asfand 
for i in range(1,157):
    os.makedirs( "C:/Users/asfan/Desktop/data/output/{}".format(i))
#######################################################################################

# %%
import time
start = time.time()

import netCDF4
import numpy as np
import pandas as pd
import xarray as xr
import os
######################(to Remove Warnings)###############################
import warnings
warnings.filterwarnings('ignore')

#######################################################
files_to_convert  = 'C:/Users/asfan/Desktop/data/netcdf/' 
#######################################################
def geo_idx(dd, dd_array):
   """
     search for nearest decimal degree in an array of decimal degrees and return the index.
     np.argmin returns the indices of minium value along an axis.
     so subtract dd from all values in dd_array, take absolute value and find index of minium.
    """
   geo_idx = (np.abs(dd_array - dd)).argmin()
   return geo_idx
############################################
for i in range(1,157):
    ## 2nd Latitude and lonitude 
    excel_dir1 = 'C:/Users/asfan/Desktop/data/output/{}/'.format(i)
    ###################(Change if needed)####################################
    #lat and lon
   # in_lat1 = 36.625
   # in_lon1 = 72.125
    if i== 1:
        in_lat1 = 36.875
        in_lon1 = 73.625
    elif i == 2:
        in_lat1 = 36.625
        in_lon1 = 72.125
    elif i == 3:
        in_lat1 = 36.625
        in_lon1 = 72.375
    elif i == 4:
        in_lat1 = 36.625
        in_lon1 = 72.625
    elif i == 5:
        in_lat1 = 36.625
        in_lon1 = 72.875
    elif i == 6:
        in_lat1 = 36.375
        in_lon1 = 71.625
    elif i == 7:
        in_lat1 = 36.375
        in_lon1 = 71.875
    elif i == 8:
        in_lat1 = 36.375
        in_lon1 = 72.125
    elif i == 9:
        in_lat1 = 36.375
        in_lon1 = 72.375
    elif i == 10:
        in_lat1 = 36.375
        in_lon1 = 72.625
    elif i == 11:
        in_lat1 = 36.125
        in_lon1 = 71.375
    elif i == 12:
        in_lat1 = 36.125
        in_lon1 = 71.625
    elif i == 13:
        in_lat1 = 36.125
        in_lon1 = 71.875   
    elif i == 14:
        in_lat1 = 36.125
        in_lon1 = 72.125
    elif i == 15:
        in_lat1 = 36.125
        in_lon1 = 72.375
    elif i == 16:
        in_lat1 = 35.875
        in_lon1 = 71.625
    elif i == 17:
        in_lat1 = 35.875
        in_lon1 = 71.875        
    elif i == 18:
        in_lat1 = 35.875
        in_lon1 = 72.125
    elif i == 19:
        in_lat1 = 35.875
        in_lon1 = 72.375
    elif i == 20:
        in_lat1 = 35.625
        in_lon1 = 71.625
    elif i == 21:
        in_lat1 = 35.625
        in_lon1 = 71.875        
    elif i == 22:
        in_lat1 = 35.625
        in_lon1 = 72.125
    elif i == 23:
        in_lat1 = 35.625
        in_lon1 = 72.375
    elif i == 24:
        in_lat1 =35.625
        in_lon1 = 72.625
    elif i == 25:
        in_lat1 = 35.625
        in_lon1 = 72.875        
    elif i == 26:
        in_lat1 =35.625
        in_lon1 = 73.125
    elif i == 27:
        in_lat1 = 35.375
        in_lon1 = 71.625 
    elif i == 28:
        in_lat1 =35.375
        in_lon1 = 71.875
    elif i == 29:
        in_lat1 = 35.375
        in_lon1 = 72.125 
    elif i == 30:
        in_lat1 = 35.375
        in_lon1 = 72.375 
    elif i == 31:
        in_lat1 =35.375
        in_lon1 = 72.625
    elif i == 32:
        in_lat1 = 35.375
        in_lon1 = 72.875
    elif i == 33:
        in_lat1 = 35.375
        in_lon1 = 73.125 
    elif i == 34:
        in_lat1 = 35.375
        in_lon1 = 73.375
    elif i == 35:
        in_lat1 = 35.375
        in_lon1 = 73.625        
    elif i == 36:
        in_lat1 = 35.125
        in_lon1 = 71.625 
    elif i == 37:
        in_lat1 =35.125
        in_lon1 = 71.875
    elif i == 38:
        in_lat1 = 35.125
        in_lon1 = 72.125 
    elif i == 39:
        in_lat1 = 35.125
        in_lon1 = 72.375 
    elif i == 40:
        in_lat1 =35.125
        in_lon1 = 72.625
    elif i == 41:
        in_lat1 = 35.125
        in_lon1 = 72.875        
    elif i == 42:
        in_lat1 = 35.125
        in_lon1 = 73.125 
    elif i == 43:
        in_lat1 = 35.125
        in_lon1 = 73.375 
    elif i == 44:
        in_lat1 =35.125
        in_lon1 = 73.625
    elif i == 45:
        in_lat1 = 35.125
        in_lon1 = 73.875 
    elif i == 46:
        in_lat1 = 35.125
        in_lon1 = 74.125 
    elif i == 47:
        in_lat1 = 34.875
        in_lon1 = 71.375 
    elif i == 48:
        in_lat1 =34.875
        in_lon1 = 71.625
    elif i == 49:
        in_lat1 = 34.875
        in_lon1 = 71.875         
    elif i == 50:
        in_lat1 = 34.875
        in_lon1 = 72.125 
    elif i == 51:
        in_lat1 = 34.875
        in_lon1 = 72.375 
    elif i == 52:
        in_lat1 =34.875
        in_lon1 = 72.625
    elif i == 53:
        in_lat1 = 34.875
        in_lon1 = 72.875 
    elif i == 54:
        in_lat1 = 34.875
        in_lon1 = 73.125 
    elif i == 55:
        in_lat1 = 34.875
        in_lon1 = 73.375 
    elif i == 56:
        in_lat1 =34.875
        in_lon1 = 73.625
    elif i == 57:
        in_lat1 = 34.875
        in_lon1 = 73.875         
    elif i == 58:
        in_lat1 = 34.625
        in_lon1 = 71.375 
    elif i == 59:
        in_lat1 = 34.625
        in_lon1 = 71.625 
    elif i == 60:
        in_lat1 =34.625
        in_lon1 = 71.875
    elif i == 61:
        in_lat1 = 34.625
        in_lon1 = 72.125 
    elif i == 62:
        in_lat1 = 34.625
        in_lon1 = 72.375 
    elif i == 63:
        in_lat1 = 34.625
        in_lon1 = 72.625 
    elif i == 64:
        in_lat1 =34.625
        in_lon1 = 72.875
    elif i == 65:
        in_lat1 = 34.625
        in_lon1 = 73.125 
    elif i == 66:
        in_lat1 = 34.625
        in_lon1 = 73.375 
    elif i == 67:
        in_lat1 = 34.625
        in_lon1 = 73.625 
    elif i == 68:
        in_lat1 = 34.375
        in_lon1 = 71.375
    elif i == 69:
        in_lat1 = 34.375
        in_lon1 = 71.625         
    elif i == 70:
        in_lat1 = 34.375
        in_lon1 = 71.875
    elif i == 71:
        in_lat1 = 34.375
        in_lon1 = 72.125
    elif i == 72:
        in_lat1 = 34.375
        in_lon1 = 72.375         
    elif i == 73:
        in_lat1 = 34.375
        in_lon1 = 72.625
    elif i == 74:
        in_lat1 = 34.375
        in_lon1 = 72.875
    elif i == 75:
        in_lat1 = 34.375
        in_lon1 = 73.125         
    elif i == 76:
        in_lat1 = 34.375
        in_lon1 = 73.375
    elif i == 77:
        in_lat1 = 34.125
        in_lon1 = 71.125
    elif i == 78:
        in_lat1 = 34.125
        in_lon1 = 71.375         
    elif i == 79:
        in_lat1 = 34.125
        in_lon1 = 71.625
    elif i == 80:
        in_lat1 = 34.125
        in_lon1 = 71.875
    elif i == 81:
        in_lat1 = 34.125
        in_lon1 = 72.125         
    elif i == 82:
        in_lat1 = 34.125
        in_lon1 = 72.375
    elif i == 83:
        in_lat1 = 34.125
        in_lon1 = 72.625
    elif i == 84:
        in_lat1 = 34.125
        in_lon1 = 72.875         
    elif i == 85:
        in_lat1 = 34.125
        in_lon1 = 73.125
    elif i == 86:
        in_lat1 = 34.125
        in_lon1 = 73.375
    elif i == 87:
        in_lat1 = 33.875
        in_lon1 = 70.125         
    elif i == 88:
        in_lat1 = 33.875
        in_lon1 = 70.375
    elif i == 89:
        in_lat1 = 33.875
        in_lon1 = 70.625
    elif i == 90:
        in_lat1 = 33.875
        in_lon1 = 70.875         
    elif i == 91:
        in_lat1 = 33.875
        in_lon1 = 71.125
    elif i == 92:
        in_lat1 = 33.875
        in_lon1 = 71.375
    elif i == 93:
        in_lat1 = 33.875
        in_lon1 = 71.625
    elif i == 94:
        in_lat1 = 33.875
        in_lon1 = 71.875         
    elif i == 95:
        in_lat1 = 33.875
        in_lon1 = 72.125
    elif i == 96:
        in_lat1 = 33.875
        in_lon1 = 72.875
    elif i == 97:
        in_lat1 = 33.875
        in_lon1 = 73.125
    elif i == 98:
        in_lat1 = 33.625
        in_lon1 = 70.375         
    elif i == 99:
        in_lat1 = 33.625
        in_lon1 = 70.625
    elif i == 100:
        in_lat1 = 33.625
        in_lon1 = 70.875
    elif i == 101:
        in_lat1 = 33.625
        in_lon1 = 71.125
    elif i == 102:
        in_lat1 = 33.625
        in_lon1 = 71.375         
    elif i == 103:
        in_lat1 = 33.625
        in_lon1 = 71.625
    elif i == 104:
        in_lat1 = 33.625
        in_lon1 = 71.875
    elif i == 105:
        in_lat1 = 33.375
        in_lon1 = 70.375
    elif i == 106:
        in_lat1 = 33.375
        in_lon1 = 70.625         
    elif i == 107:
        in_lat1 = 33.375
        in_lon1 = 70.875
    elif i == 108:
        in_lat1 = 33.375
        in_lon1 = 71.125
    elif i == 109:
        in_lat1 = 33.375
        in_lon1 = 71.375
    elif i == 110:
        in_lat1 = 33.375
        in_lon1 = 71.625         
    elif i == 111:
        in_lat1 = 33.125
        in_lon1 = 70.125
    elif i == 112:
        in_lat1 = 33.125
        in_lon1 = 70.375
    elif i == 113:
        in_lat1 = 33.125
        in_lon1 = 70.625
    elif i == 114:
        in_lat1 = 33.125
        in_lon1 = 70.875         
    elif i == 115:
        in_lat1 = 33.125
        in_lon1 = 71.125                                                                                                        
    elif i == 116:
        in_lat1 = 33.125
        in_lon1 = 71.375
    elif i == 117:
        in_lat1 = 33.125
        in_lon1 = 71.625
    elif i == 118:
        in_lat1 = 32.875
        in_lon1 = 69.625         
    elif i == 119:
        in_lat1 = 32.875
        in_lon1 = 69.875 
    elif i == 120:
        in_lat1 = 32.875
        in_lon1 = 70.125
    elif i == 121:
        in_lat1 = 32.875
        in_lon1 = 70.375
    elif i == 122:
        in_lat1 = 32.875
        in_lon1 = 70.625         
    elif i == 123:
        in_lat1 = 32.875
        in_lon1 = 70.875
    elif i == 124:
        in_lat1 = 32.875
        in_lon1 = 71.125
    elif i == 125:
        in_lat1 = 32.625
        in_lon1 = 69.625
    elif i == 126:
        in_lat1 = 32.625
        in_lon1 = 69.875         
    elif i == 127:
        in_lat1 = 32.625
        in_lon1 = 70.125
    elif i == 128:
        in_lat1 = 32.625
        in_lon1 = 70.375
    elif i == 129:
        in_lat1 = 32.625
        in_lon1 = 70.625
    elif i == 130:
        in_lat1 = 32.625
        in_lon1 = 70.875         
    elif i == 131:
        in_lat1 = 32.625
        in_lon1 = 71.125        
    elif i == 132:
        in_lat1 = 32.375
        in_lon1 = 69.375
    elif i == 133:
        in_lat1 = 32.375
        in_lon1 = 69.625 
    elif i == 134:
        in_lat1 = 32.375
        in_lon1 = 69.875
    elif i == 135:
        in_lat1 = 32.375
        in_lon1 = 70.125  
    elif i == 136:
        in_lat1 = 32.375
        in_lon1 = 70.375
    elif i == 137:
        in_lat1 = 32.375
        in_lon1 = 70.625         
    elif i == 138:
        in_lat1 = 32.375
        in_lon1 = 70.875  
    elif i == 139:
        in_lat1 = 32.375
        in_lon1 = 71.125
    elif i == 140:
        in_lat1 = 32.125
        in_lon1 = 69.375
    elif i == 141:
        in_lat1 = 32.125
        in_lon1 = 69.625         
    elif i == 142:
        in_lat1 = 32.125
        in_lon1 = 69.875  
    elif i == 143:
        in_lat1 = 32.125
        in_lon1 = 70.125
    elif i == 144:
        in_lat1 = 32.125
        in_lon1 = 70.375        
    elif i == 145:
        in_lat1 = 32.125
        in_lon1 = 70.625  
    elif i == 146:
        in_lat1 = 32.125
        in_lon1 = 70.875
    elif i == 147:
        in_lat1 = 31.875
        in_lon1 = 69.875
    elif i == 148:
        in_lat1 = 31.875
        in_lon1 = 70.125      
    elif i == 149:
        in_lat1 = 31.875
        in_lon1 = 70.375
    elif i == 150:
        in_lat1 = 31.875
        in_lon1 = 70.625
    elif i == 151:
        in_lat1 = 31.875
        in_lon1 = 70.875
    elif i == 152:
        in_lat1 = 31.625
        in_lon1 = 70.125
    elif i == 153:
        in_lat1 = 31.625
        in_lon1 = 70.375
    elif i == 154:
        in_lat1 = 31.625
        in_lon1 = 70.625
    elif i == 155:
        in_lat1 = 31.375
        in_lon1 = 70.375
    elif i == 156:
        in_lat1 = 31.375
        in_lon1 = 70.625
    for filename in os.listdir(files_to_convert):
        f = netCDF4.Dataset(files_to_convert + filename)
        lats = f.variables['lat'][:]
        lons = f.variables['lon'][:]
        lat_idx1 = geo_idx(in_lat1, lats)
        lon_idx1 = geo_idx(in_lon1, lons)
        #print(lat_idx1)
        #print(lon_idx1)
        precip = f.variables["precipitation"]
        
        B = precip[lon_idx1,lat_idx1]
        my_array = np.array([B])
        df2 = pd.DataFrame(my_array, columns = ['precipitation'])
        #print(df2)
        df2.to_excel(excel_dir1 + filename +"output.xlsx") 
        
end = time.time()
print(end - start)
# Out:
# 18.93699598312378
